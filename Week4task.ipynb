# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyCharalambous/EmilyCharalambous.github.io/blob/main/Week4task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('Population_growth.csv')

# %%
df.head(1)
# Out:
#   Country Name Country Code                Indicator Name Indicator Code  \
# 0        Aruba          ABW  Population growth (annual %)    SP.POP.GROW
#
#    1960      1961      1962      1963      1964      1965  ...      2012  \
# 0   NaN  2.236462  1.432843  0.823502  0.580334  0.573498  ...  0.503385
#
#       2013      2014      2015     2016      2017      2018      2019  \
# 0  0.58329  0.590508  0.541048  0.50286  0.471874  0.459266  0.437415
#
#        2020      2021
# 0  0.428017  0.401008
#
# [1 rows x 66 columns]

# %%
df
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  Population growth (annual %)
# 1    Africa Eastern and Southern          AFE  Population growth (annual %)
# 2                    Afghanistan          AFG  Population growth (annual %)
# 3     Africa Western and Central          AFW  Population growth (annual %)
# 4                         Angola          AGO  Population growth (annual %)
# ..                           ...          ...                           ...
# 261                       Kosovo          XKX  Population growth (annual %)
# 262                  Yemen, Rep.          YEM  Population growth (annual %)
# 263                 South Africa          ZAF  Population growth (annual %)
# 264                       Zambia          ZMB  Population growth (annual %)
# 265                     Zimbabwe          ZWE  Population growth (annual %)
#
# ...

# %%
df2 =df.drop(['Indicator Name','Indicator Code'],axis=1)

# %%
df3 = df2.set_index(['Country Code','Country Name']).stack().reset_index()

# %%
df3.columns
# Out:
# Index(['Country Code', 'Country Name', 'level_2', 0], dtype='object')

# %%
df4 = df3.rename(columns={'level_2':'Year', 0:'Population growth (annual %)'})

# %%
df4.set_index('Country Code').to_csv('mycsv.csv')

# %%
df4.set_index('Country Code').to_csv('')

# %%
# df3.set_index(['level_2', 'Couuntry Code', 'Country Name']).unstack(['Country Code', 'Country Name'])

# %%
list ( df.T.to_dict().values() )
# Out:
# [{'Country Name': 'Aruba',
#   'Country Code': 'ABW',
#   'Indicator Name': 'Population growth (annual %)',
#   'Indicator Code': 'SP.POP.GROW',
#   '1960': nan,
#   '1961': 2.236462489,
#   '1962': 1.432843226,
#   '1963': 0.823501772,
#   '1964': 0.580333649,
#   '1965': 0.573498328,
#   '1966': 0.599694129,
#   '1967': 0.590950867,
#   '1968': 0.572063302,
#   '1969': 0.609679886,
#   '1970': 0.570440581,
#   '1971': 0.62778659,
#   '1972': 0.682367621,
#   '1973': 0.64454568,
#   '1974': 0.481936625,
#   '1975': 0.207955183,
#   '1976': -0.110525502,
#   '1977': -0.363781075,
#   '1978': -0.438291368,
#   '1979': -0.216533223,
#   '1980': 0.208213686,
#   '1981': 0.769119805,
#   '1982': 1.279733959,
#   '1983': 1.411551999,
#   '1984': 0.980501941,
#   '1985': 0.31466057,
#   '1986': -0.603173653,
#   '1987': -1.296580747,
#   '1988': -1.246456623,
#   '1989': -0.06387945,
#   '1990': 1.816829615,
#   '1991': 3.898738693,
#   '1992': 5.446051861,
#   '1993': 6.048669078,
# ...

# %%
exported_values = list( df.T.to_dict().values() )

# %%
import json

# %%
open('my_first_json_file.json', 'w').write( json.dumps(exported_values) )
# Out:
# 379990
